# %% [markdown]
# # Data Analytics Real Time Project

# %% [markdown]
# - Big Basket Analytics project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BigBasket Products.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Head

df.head(8)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
# 5      6                  Germ - Removal Multipurpose Wipes
# 6      7                                       Multani Mati
# 7      8                  Hand Sanitizer - 70% Alcohol Base
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
# ...

# %%
# Description

df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
# Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Delete Column index

df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Full Stock Capacity. (Price).
df.sale_price.sum()
# Out:
# 9219228.53

# %%
# Discount Ratio

df.market_price.sum()
# Out:
# 10527571.39

# %%
df.market_price.sum() - df.sale_price.sum()
# Out:
# 1308342.8600000013

# %%
# Univariate ANalysis...

df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# How many sub catergories in single category.

df.groupby('category')['sub_category'].value_counts().head(50)
# Out:
# category                  sub_category
# Baby Care                 Diapers & Wipes              247
#                           Baby Bath & Hygiene          206
#                           Feeding & Nursing             48
#                           Baby Food & Formula           47
#                           Baby Accessories              37
#                           Mothers & Maternity           24
#                           Atta, Flours & Sooji           1
# Bakery, Cakes & Dairy     Dairy                        385
#                           Cookies, Rusk & Khari        153
#                           Cakes & Pastries             125
#                           Breads & Buns                 48
#                           Ice Creams & Desserts         48
#                           Gourmet Breads                35
#                           Non Dairy                     32
#                           Bakery Snacks                 25
# ...

# %%
df.groupby('category')['sale_price'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            3295574.24
# Kitchen, Garden & Pets      1817723.12
# Gourmet & World Food        1500115.31
# Cleaning & Household         605043.09
# Foodgrains, Oil & Masala     516916.23
# Snacks & Branded Foods       364675.08
# Baby Care                    326317.17
# Beverages                    212186.67
# Bakery, Cakes & Dairy        121525.14
# Eggs, Meat & Fish            101114.12
# Fruits & Vegetables           28345.36
# Name: sale_price, dtype: float64

# %%
df.groupby('category')['sale_price'].sum().sort_values(ascending=False).plot(kind='pie',autopct='%1.f%%',shadow=True)
# Out:
# <Axes: ylabel='sale_price'>

# %%
# We've to create a new Column discount and add discount amount in it.


df['discount']  = df.market_price - df.sale_price

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
df.discount.max()
# Out:
# 4320.0

# %%
df.discount.sum()
# Out:
# 1307730.86

# %%
df.discount.min()
# Out:
# -110360.0

# %%
# OUTLIERS DETECTION

sns.boxplot(df.market_price)
# Out:
# <Axes: ylabel='market_price'>

# %%
sns.boxplot(df.sale_price)
# Out:
# <Axes: ylabel='sale_price'>

# %%
# Data Visualization

sns.scatterplot(x=df.sale_price,y=df.market_price)
# Out:
# <Axes: xlabel='sale_price', ylabel='market_price'>

# %%
# Data Filteration

df[df.sale_price>20000]
# Out:
#                                                 product  \
# 248   4mm Aluminium Induction Base Chapati Roti Tawa...
# 288           Arrabbiata Tomato Pasta Sauce With Chilli
# 436                        Balloon - Polka Dot, 12 Inch
# 1249                                          Beard Kit
#
#                     category            sub_category       brand  sale_price  \
# 248   Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288     Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 436     Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249        Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
#
#       market_price                      type  rating  \
# 248         1289.0          Tawa & Sauce Pan     NaN
# 288          325.0   Mustard & Cheese Sauces     5.0
# 436          129.0  Caps, Balloons & Candles     3.9
# 1249        3300.0        Combos & Gift Sets     NaN
#
# ...

# %%
# Fill sale price that is more that 20000 replace it with market price.


df.sale_price = np.where(df.sale_price>20000,df.market_price,df.sale_price)

# %%
df[248:249]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
#
#      market_price              type  rating  \
# 248        1289.0  Tawa & Sauce Pan     NaN
#
#                                            description  discount
# 248  Hazel Aluminium Tawa has an ergonomic design f... -110360.0

# %%
sns.scatterplot(x=df.market_price,y=df.sale_price)
# Out:
# <Axes: xlabel='market_price', ylabel='sale_price'>

# %%
df.sale_price.max()
# Out:
# 12500.0

# %%
df[df.sale_price==df.sale_price.max()]
# Out:
#                product                category            sub_category brand  \
# 25301  Bravura Clipper  Kitchen, Garden & Pets  Pet Food & Accessories  Wahl
#
#        sale_price  market_price                     type  rating  \
# 25301     12500.0       12500.0  Pet Cleaning & Grooming     NaN
#
#                                              description  discount
# 25301  The bravura clipper is a must-have clipper for...       0.0

# %%
df.sale_price.min()
# Out:
# 2.45

# %%
df[df.sale_price==df.sale_price.min()]
# Out:
#             product             category        sub_category   brand  \
# 26976  Curry Leaves  Fruits & Vegetables  Herbs & Seasonings  Fresho
#
#        sale_price  market_price                   type  rating  \
# 26976        2.45          15.0  Indian & Exotic Herbs     NaN
#
#                                              description  discount
# 26976  With dark green and glossy appearance, curry l...     12.55

# %%
# Check for Null Values

df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
df.rating.mean()
# Out:
# 3.9432951001638563

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
df['product'] = df['product'].fillna('unknown')
df.brand = df.brand.fillna('unknown')
df.sale_price = df.sale_price.fillna(df.market_price)
df.rating = df.rating.fillna(df.rating.mean())
df.description = df.description.fillna('unknown')
df.discount = df.discount.fillna(0)

# %%
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# discount        0
# dtype: int64
